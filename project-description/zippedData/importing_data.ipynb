# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os

# %%
path = '/Users/bradleysawyer/fis/project1/project-description/zippedData'
folder_files = os.listdir(path)
folder_files
print('All files in directory:', '\n', folder_files, '\n')
data_files= []
for file in folder_files: 
     if file.endswith('.csv'):
        data_files.append(file)
print('.csv files:', '\n', data_files, '\n')

placeholder = [file[:-4].replace('.', '_') for file in data_files]
print('renamed files:', '\n', placeholder)
for index in range(len(placeholder)):
    placeholder[index]  = pd.read_csv(path + '/' + data_files[index])
# Out:
# All files in directory:
#  ['.DS_Store', '~$related imdb and finance data.xlsx', 'tmdb.movies.csv', 'imdb.title.crew.csv', 'rt.reviews.tsv', 'tn.movie_budgets.csv', 'imdb.title.ratings.csv', 'importing_data.ipynb', 'imdb.name.basics.csv', 'imdb.title.principals.csv', 'imdb.title.akas.csv', 'related imdb and finance data.xlsx', 'bom.movie_gross.csv', 'imdb.title.basics.csv', 'rt.movie_info.tsv', '.ipynb_checkpoints', 'merging_data.ipynb']
#
# .csv files:
#  ['tmdb.movies.csv', 'imdb.title.crew.csv', 'tn.movie_budgets.csv', 'imdb.title.ratings.csv', 'imdb.name.basics.csv', 'imdb.title.principals.csv', 'imdb.title.akas.csv', 'bom.movie_gross.csv', 'imdb.title.basics.csv']
#
# renamed files:
#  ['tmdb_movies', 'imdb_title_crew', 'tn_movie_budgets', 'imdb_title_ratings', 'imdb_name_basics', 'imdb_title_principals', 'imdb_title_akas', 'bom_movie_gross', 'imdb_title_basics']

# %%
#assigning datasets to variables
tmdb_movies = placeholder[0]
imdb_title_crew = placeholder[1]
tn_movie_budgets = placeholder[2]
imdb_title_ratings = placeholder[3]
imdb_name_basics = placeholder[4]
imdb_title_principals = placeholder[5]
imdb_title_akas = placeholder[6]
bom_movie_gross = placeholder[7]
imdb_title_basics = placeholder[8]

# %%
# dataframes ={}
# for key in placeholder.keys():
#     data = placeholder[key][:-4].replace('.', '_')
#     dataframes[data] = placeholder[key]
# print('dictionary of dataframes:', '\n', dataframes)

# %%
# for key, value in dataframes.items():
#     print('first line of', dataframes[key],':')
#     key  = pd.read_csv(path + '/' + value)
#     print(key.head(0), '\n')
# return key

# %%
# dataframes ={}
# for key in placeholder.keys():
#     data = placeholder[key].replace('.', '_')
#     dataframes[data] = placeholder[key]
# print(dataframes)

# %%
# print(tmdb_movies.info(),'\n')

# print(tmdb_movies.describe(),'\n')

# for col in tmdb_movies.columns:
#     print(f"top 5 values: {col}",'\n',tmdb_movies[col].sort_values().head(5),'\n''\n')
#     print(f"bottom values: {col}", '\n', tmdb_movies[col].sort_values(ascending=False).head(5),'\n''\n')

# duplicates = tmdb_movies[tmdb_movies.duplicated()]
# print('number of duplicate rows', len(duplicates),'\n')
# print('sample of duplicates rows:',duplicates.head(),'\n')

# duplicates_ids = tmdb_movies[tmdb_movies.duplicated(subset='id')]
# print('number of duplicate ids:',len(duplicates_ids),'\n')
# print('sample of duplicates rows:',duplicates_ids.head(),'\n')

# for col in tmdb_movies.columns:
#     print(col, '\n', tmdb_movies[col].value_counts(normalize=True).head(), '\n\n')

# %%
for index in range(len(placeholder)):
    print("index:", index)
    print(placeholder[index].info(),'\n')
    print(placeholder[index].describe(),'\n')

    for col in placeholder[index].columns:
        print(f"top 5 values: {col}",'\n',placeholder[index][col].sort_values().head(5),'\n''\n')
        print(f"bottom values: {col}", '\n', placeholder[index][col].sort_values(ascending=False).head(5),'\n''\n')

    duplicates = placeholder[index][placeholder[index].duplicated()]
    print('number of duplicate rows', len(duplicates),'\n')
    print('sample of duplicates rows:',duplicates.head(),'\n')

#     duplicates_ids = placeholder[index][placeholder[index].duplicated(subset='id')]
#     print('number of duplicate ids:',len(duplicates_ids),'\n')
#     print('sample of duplicates rows:',duplicates_ids.head(),'\n')

#     for col in placeholder[index].columns:
#         print(col, '\n', tmdb_movies[col].value_counts(normalize=True).head(), '\n\n')
# Out:
# index: 0
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26517 entries, 0 to 26516
# Data columns (total 10 columns):
# Unnamed: 0           26517 non-null int64
# genre_ids            26517 non-null object
# id                   26517 non-null int64
# original_language    26517 non-null object
# original_title       26517 non-null object
# popularity           26517 non-null float64
# release_date         26517 non-null object
# title                26517 non-null object
# vote_average         26517 non-null float64
# vote_count           26517 non-null int64
# dtypes: float64(2), int64(3), object(5)
# memory usage: 2.0+ MB
# None
#
#         Unnamed: 0             id    popularity  vote_average    vote_count
# count  26517.00000   26517.000000  26517.000000  26517.000000  26517.000000
# mean   13258.00000  295050.153260      3.130912      5.991281    194.224837
# std     7654.94288  153661.615648      4.355229      1.852946    960.961095
# ...

# %%
data_files
# Out:
# ['tmdb.movies.csv',
#  'imdb.title.crew.csv',
#  'tn.movie_budgets.csv',
#  'imdb.title.ratings.csv',
#  'imdb.name.basics.csv',
#  'imdb.title.principals.csv',
#  'imdb.title.akas.csv',
#  'bom.movie_gross.csv',
#  'imdb.title.basics.csv']

# %%
print(imdb_title_basics.head())
print(imdb_title_crew.head())
# Out:
#       tconst                    primary_title              original_title  \
# 0  tt0063540                        Sunghursh                   Sunghursh
# 1  tt0066787  One Day Before the Rainy Season             Ashad Ka Ek Din
# 2  tt0069049       The Other Side of the Wind  The Other Side of the Wind
# 3  tt0069204                  Sabse Bada Sukh             Sabse Bada Sukh
# 4  tt0100275         The Wandering Soap Opera       La Telenovela Errante
#
#    start_year  runtime_minutes                genres
# 0        2013            175.0    Action,Crime,Drama
# 1        2019            114.0       Biography,Drama
# 2        2018            122.0                 Drama
# 3        2018              NaN          Comedy,Drama
# 4        2017             80.0  Comedy,Drama,Fantasy
#       tconst                      directors              writers
# 0  tt0285252                      nm0899854            nm0899854
# 1  tt0438973                            NaN  nm0175726,nm1802864
# ...

# %%
print('shape:',imdb_title_basics.shape, imdb_title_crew.shape)
print('unique ids:', imdb_title_basics.tconst.str.strip("").nunique(), imdb_title_crew.tconst.str.strip("").nunique())
# Out:
# shape: (146144, 6) (146144, 3)
# unique ids: 146144 146144

# %%
#creating merged dataframe
title_crew_df = pd.merge(imdb_title_basics, imdb_title_crew, how='inner', on='tconst')
title_crew_df.head()
# Out:
#       tconst                    primary_title              original_title  \
# 0  tt0063540                        Sunghursh                   Sunghursh
# 1  tt0066787  One Day Before the Rainy Season             Ashad Ka Ek Din
# 2  tt0069049       The Other Side of the Wind  The Other Side of the Wind
# 3  tt0069204                  Sabse Bada Sukh             Sabse Bada Sukh
# 4  tt0100275         The Wandering Soap Opera       La Telenovela Errante
#
#    start_year  runtime_minutes                genres            directors  \
# 0        2013            175.0    Action,Crime,Drama            nm0712540
# 1        2019            114.0       Biography,Drama            nm0002411
# 2        2018            122.0                 Drama            nm0000080
# 3        2018              NaN          Comedy,Drama            nm0611531
# 4        2017             80.0  Comedy,Drama,Fantasy  nm0765384,nm0749914
#
#                                    writers
# ...

# %%
print('unique ids:', title_crew_df.tconst.str.strip("").nunique())
# Out:
# unique ids: 146144

# %%
movies_df = title_crew_df.copy()

# %%
print(imdb_title_ratings.head())
print(imdb_title_principals.head())
# Out:
#        tconst  averagerating  numvotes
# 0  tt10356526            8.3        31
# 1  tt10384606            8.9       559
# 2   tt1042974            6.4        20
# 3   tt1043726            4.2     50352
# 4   tt1060240            6.5        21
#       tconst  ordering     nconst  category       job        characters
# 0  tt0111414         1  nm0246005     actor       NaN       ["The Man"]
# 1  tt0111414         2  nm0398271  director       NaN               NaN
# 2  tt0111414         3  nm3739909  producer  producer               NaN
# 3  tt0323808        10  nm0059247    editor       NaN               NaN
# 4  tt0323808         1  nm3579312   actress       NaN  ["Beth Boothby"]
